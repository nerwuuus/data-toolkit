# %%
# ====================================================================================
# Install SQL libraries using PowerShell:
#   pip install sqlalchemy
#   pip install sqlalchemy pg8000
# SQLAlchemy: Python library for database access and ORM (Object Relational Mapping).
# PG8000: Pure-Python driver for connecting to PostgreSQL databases.
# ====================================================================================

import pandas as pd
from sqlalchemy import create_engine

# %%
# PostgreSQL connection details
username = 'postgres'
password = 'admin'
host = 'localhost'
port = '5432'
database = 'weather_analytics'

# Create connection using create_engine (which acts as 
# the main interface between Python code and the database)
engine = create_engine(
    f'postgresql+pg8000://{username}:{password}@{host}:{port}/{database}'
    )

# %%
# Fetch the data from PostgreSQL weather_analytics server - gold layer
df_raw = pd.read_sql(
    'SELECT * ' \
    'FROM gold.weather_observations',
    con=engine 
    # con=engine in pd.read_sql() tells pandas which 
    # database connection to use when executing the SQL query
)
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# File c:\Users\zychl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pg8000\legacy.py:253, in Cursor.execute(self, operation, args, stream)
#     252 if len(args) == 0 and stream is None:
# --> 253     self._context = self._c.execute_simple(operation)
#     254 else:
#
# File c:\Users\zychl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pg8000\core.py:694, in CoreConnection.execute_simple(self, statement)
#     693 _flush(self._sock)
# --> 694 self.handle_messages(context)
#     696 return context
#
# File c:\Users\zychl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pg8000\core.py:844, in CoreConnection.handle_messages(self, context)
#     843 if context.error is not None:
# --> 844     raise context.error
#
# DatabaseError: {'S': 'BŁĄD', 'V': 'ERROR', 'C': '42P01', 'M': 'relacja "gold.weather_observations" nie istnieje', 'P': '15', 'F': 'parse_relation.c', 'L': '1448', 'R': 'parserOpenTable'}
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# File c:\Users\zychl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sqlalchemy\engine\base.py:1969, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1968     if not evt_handled:
# -> 1969         self.dialect.do_execute(
#    1970             cursor, str_statement, effective_parameters, context
#    1971         )
#    1973 if self._has_events or self.engine._has_events:
#
# File c:\Users\zychl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sqlalchemy\engine\default.py:952, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     951 def do_execute(self, cursor, statement, parameters, context=None):
# --> 952     cursor.execute(statement, parameters)
#
# File c:\Users\zychl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pg8000\legacy.py:283, in Cursor.execute(self, operation, args, stream)
#     281         cls = ProgrammingError
# --> 283     raise cls(msg)
#     284 else:
#
# ProgrammingError: {'S': 'BŁĄD', 'V': 'ERROR', 'C': '42P01', 'M': 'relacja "gold.weather_observations" nie istnieje', 'P': '15', 'F': 'parse_relation.c', 'L': '1448', 'R': 'parserOpenTable'}
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# File c:\Users\zychl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\io\sql.py:1679, in SQLDatabase.execute(self, sql, params)
#    1678 try:
# -> 1679     return execute_function(sql, *args)
#    1680 except SQLAlchemyError as exc:
#
# File c:\Users\zychl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sqlalchemy\engine\base.py:1781, in Connection.exec_driver_sql(self, statement, parameters, execution_options)
#    1780 dialect = self.dialect
# -> 1781 ret = self._execute_context(
#    1782     dialect,
#    1783     dialect.execution_ctx_cls._init_statement,
#    1784     statement,
#    1785     None,
#    1786     execution_options,
#    1787     statement,
#    1788     distilled_parameters,
#    1789 )
#    1791 return ret
#
# File c:\Users\zychl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sqlalchemy\engine\base.py:1848, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1847 else:
# -> 1848     return self._exec_single_context(
#    1849         dialect, context, statement, parameters
#    1850     )
#
# File c:\Users\zychl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sqlalchemy\engine\base.py:1988, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1987 except BaseException as e:
# -> 1988     self._handle_dbapi_exception(
#    1989         e, str_statement, effective_parameters, cursor, context
#    1990     )
#    1992 return result
#
# File c:\Users\zychl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sqlalchemy\engine\base.py:2365, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2364     assert sqlalchemy_exception is not None
# -> 2365     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2366 else:
#
# File c:\Users\zychl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sqlalchemy\engine\base.py:1969, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1968     if not evt_handled:
# -> 1969         self.dialect.do_execute(
#    1970             cursor, str_statement, effective_parameters, context
#    1971         )
#    1973 if self._has_events or self.engine._has_events:
#
# File c:\Users\zychl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sqlalchemy\engine\default.py:952, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     951 def do_execute(self, cursor, statement, parameters, context=None):
# --> 952     cursor.execute(statement, parameters)
#
# File c:\Users\zychl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pg8000\legacy.py:283, in Cursor.execute(self, operation, args, stream)
#     281         cls = ProgrammingError
# --> 283     raise cls(msg)
#     284 else:
#
# ProgrammingError: (pg8000.dbapi.ProgrammingError) {'S': 'BŁĄD', 'V': 'ERROR', 'C': '42P01', 'M': 'relacja "gold.weather_observations" nie istnieje', 'P': '15', 'F': 'parse_relation.c', 'L': '1448', 'R': 'parserOpenTable'}
# [SQL: SELECT * FROM gold.weather_observations]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Fetch the data from PostgreSQL weather_analytics server - gold layer
# ----> 2 df_raw = pd.read_sql(
#       3     'SELECT * ' \
#       4     'FROM gold.weather_observations',
#       5     con=engine
#
# File c:\Users\zychl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\io\sql.py:730, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     720     return pandas_sql.read_table(
#     721         sql,
#     722         index_col=index_col,
#    (...)    727         dtype_backend=dtype_backend,
#     728     )
#     729 else:
# --> 730     return pandas_sql.read_query(
#     731         sql,
#     732         index_col=index_col,
#     733         params=params,
#     734         coerce_float=coerce_float,
#     735         parse_dates=parse_dates,
#     736         chunksize=chunksize,
#     737         dtype_backend=dtype_backend,
#     738         dtype=dtype,
#     739     )
#
# File c:\Users\zychl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\io\sql.py:1856, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    1801 def read_query(
#    1802     self,
#    1803     sql: str,
#    (...)   1810     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    1811 ) -> DataFrame | Iterator[DataFrame]:
#    1812     """
#    1813     Read SQL query into a DataFrame.
#    1814
#    (...)   1854
#    1855     """
# -> 1856     result = self.execute(sql, params)
#    1857     columns = result.keys()
#    1859     if chunksize is not None:
#
# File c:\Users\zychl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\io\sql.py:1681, in SQLDatabase.execute(self, sql, params)
#    1679     return execute_function(sql, *args)
#    1680 except SQLAlchemyError as exc:
# -> 1681     raise DatabaseError(f"Execution failed on sql '{sql}': {exc}") from exc
#
# DatabaseError: Execution failed on sql 'SELECT * FROM gold.weather_observations': (pg8000.dbapi.ProgrammingError) {'S': 'BŁĄD', 'V': 'ERROR', 'C': '42P01', 'M': 'relacja "gold.weather_observations" nie istnieje', 'P': '15', 'F': 'parse_relation.c', 'L': '1448', 'R': 'parserOpenTable'}
# [SQL: SELECT * FROM gold.weather_observations]
# (Background on this error at: https://sqlalche.me/e/20/f405)
